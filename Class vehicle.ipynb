# %%
# Parent class
class Vehicle:
    def __init__(self,brand,speed):
        self.brand = brand
        self.speed = speed
    def start(self):
        return f"{self.brand} vehicle is starting..."
    def stop(self):
        return f"{self.brand} vehicle is stopping..."
    

class Car(Vehicle):
    def __init__(self,brand,speed,model,fuel_type):
        #Parent constructor call
        super().__init__(brand,speed)
        self.model = model
        self.fuel_type = fuel_type
    def car_info(self):
        return f"Car:{self.brand}{self.model},Speed:{self.speed} km/h, Fuel: {self.fuel_type}"
    
    # Different Car Objects 
car1 = Car("Toyota",180, "Corolla","Petrol")
car2 = Car("Honda",200,"Civic","petrol")
car3 = Car("Tesla",250,"Model S","Electric")

    #printing Details 
print(car1.car_info())
print(car1.start())
print()

print(car2.car_info())
print(car2.start())
print()

print(car3.car_info())
print(car3.start())
# Out:
# Car:ToyotaCorolla,Speed:180 km/h, Fuel: Petrol
# Toyota vehicle is starting...
#
# Car:HondaCivic,Speed:200 km/h, Fuel: petrol
# Honda vehicle is starting...
#
# Car:TeslaModel S,Speed:250 km/h, Fuel: Electric
# Tesla vehicle is starting...
